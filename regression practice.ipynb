# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import statsmodels.formula.api as smf

# %%
data = pd.read_csv("NewspaperData.csv")

# %%
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
sns.distplot(data['sunday'])
# Out:
# <AxesSubplot:xlabel='sunday', ylabel='Density'>

# %%
sns.dist(data['daily'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9776\566509654.py in <module>
# ----> 1 sns.dist(data['daily'])
#
# AttributeError: module 'seaborn' has no attribute 'dist'

# %%
sns.distplot(sqrt(data['daily']))
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='daily', ylabel='Density'>

# %%
from numpy import log

# %%
sns.distplot(log(data['daily']))
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='daily', ylabel='Density'>

# %%
sns.regplot(data=data,x='daily',y='sunday')
# Out:
# <AxesSubplot:xlabel='daily', ylabel='sunday'>

# %%
sns.pairplot((data))

# %%
model=smf.ols("sunday~daily",data=data).fit()

# %%
model.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
model.rsquared
# Out:
# 0.9180596895873294

# %%
model.rsquared_adj
# Out:
# 0.9154990548869335

# %%
model.pvalues
# Out:
# Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
model.tvalues
# Out:
# Intercept     0.386427
# daily        18.934840
# dtype: float64

# %%
predict=model.predict(data['daily'])

# %%
data['predict']=predict

# %%
data
# Out:
#                          Newspaper     daily    sunday      predict
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
data=data['sunday']-predict

# %%
sns.distplot(data)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
newdata=pd.Series([355,238])

# %%
newdata
# Out:
# 0    355
# 1    238
# dtype: int64

# %%
newdata=pd.DataFrame(newdata,columns=['daily'])

# %%
newdata
# Out:
#    daily
# 0    355
# 1    238

# %%
model.predict(newdata)
# Out:
# 0    489.434369
# 1    332.687742
# dtype: float64

# %%
import numpy as np
from scipy import stats

# Generate some random data

# %%
data = np.random.randn(100)

# %%
import pandas as pd
import seaborn as sns

# %%
# Calculate the Z-scores
z_scores = np.abs(stats.zscore(data))
z_scores
# Out:
# array([0.57408747, 0.69691483, 0.75897508, 1.1978544 , 0.41453124,
#        0.58299553, 0.0721633 , 1.12932854, 0.14175895, 0.75574893,
#        0.3041554 , 2.50882644, 0.34069872, 0.36264915, 0.05372474,
#        1.45208885, 0.39200518, 0.64201003, 1.45634066, 0.54766681,
#        0.54433317, 0.30653314, 0.77029665, 0.58535854, 0.10615866,
#        0.51549677, 0.91368669, 0.1372963 , 0.02868884, 0.09306141,
#        0.73876826, 1.09010392, 0.01972117, 1.13731809, 1.61513638,
#        0.0882205 , 0.61303257, 0.3804679 , 0.01616463, 0.0359172 ,
#        0.20240507, 0.95890809, 0.53148209, 0.64593903, 0.6562501 ,
#        0.73051412, 1.20277003, 0.28250053, 0.84292308, 0.29266331,
#        0.12435829, 1.00688229, 1.36288324, 0.79050219, 0.61088418,
#        2.33585232, 0.43615086, 1.27397767, 0.33327919, 0.35403823,
#        0.69331029, 0.29973528, 0.80835591, 2.79250541, 2.55607583,
#        1.135588  , 0.33577236, 0.4543694 , 0.33749237, 1.79184777,
# ...

# %%
sns.boxplot(data)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Identify the outliers
threshold = 3
outliers = np.where(z_scores > threshold)[0]

# %%
# Remove the outliers from the data
clean_data = np.delete(data, outliers)
